# %% [markdown]
# Q1: What is the difference between a t-test and a z-test? Provide an example scenario where you would
# use each type of test.
#
#
# The t-test and the z-test are both statistical tests used to make inferences about population parameters based on sample data. The key difference between them lies in the assumptions made about the population and the available information.
#
# A t-test is used when the population standard deviation is unknown and must be estimated from the sample. It is suitable for small sample sizes (typically less than 30) and follows a t-distribution. The t-test is commonly used to compare means between two groups or to determine if a sample mean differs significantly from a known population mean.
#
# Example scenario for using a t-test:
# Let's say a researcher wants to investigate whether a new teaching method improves student performance. They randomly select two groups of students, one taught using the traditional method and the other taught using the new method. After collecting test scores from both groups, the researcher can perform a t-test to determine if there is a significant difference in the mean scores between the two groups.
#
# On the other hand, a z-test is used when the population standard deviation is known or when the sample size is large (typically greater than 30), allowing for an approximation of the normal distribution. The z-test is commonly employed when comparing sample proportions or testing hypotheses about a population mean.
#
# Example scenario for using a z-test:
# Suppose a company claims that their product has a defect rate of less than 2%. To verify this claim, a quality control manager takes a large random sample of products and inspects them for defects. By conducting a z-test on the sample proportion of defects, the manager can determine if there is sufficient evidence to support or reject the company's claim.
#
# In summary, the choice between a t-test and a z-test depends on the sample size and the availability of population standard deviation information. If the sample size is small or the population standard deviation is unknown, a t-test is appropriate. If the sample size is large and the population standard deviation is known or can be reasonably estimated, a z-test can be used.

# %% [markdown]
# Q2: Differentiate between one-tailed and two-tailed tests. short
#
#
# A one-tailed test is used when the alternative hypothesis specifies the direction of the effect, while a two-tailed test is used when the alternative hypothesis does not specify the direction.
#
# In a one-tailed test, statistical significance is assessed by examining whether the observed data significantly deviate from the null hypothesis in only one direction (positive or negative). It focuses on detecting an effect in a specific direction.
#
# In a two-tailed test, statistical significance is assessed by examining whether the observed data significantly deviate from the null hypothesis in either direction. It considers the possibility of an effect in both directions.

# %% [markdown]
# Q3: Explain the concept of Type 1 and Type 2 errors in hypothesis testing. Provide an example scenario for
# each type of error.
#
#
# In hypothesis testing, Type 1 and Type 2 errors are two types of mistakes that can occur when making decisions about the null and alternative hypotheses.
#
# Type 1 error, also known as a false positive, occurs when the null hypothesis is rejected even though it is true. In other words, it is the incorrect rejection of a true null hypothesis. It represents the situation where the test results lead to concluding that there is an effect or relationship when, in reality, there is none.
#
# Example scenario of a Type 1 error:
# Let's say a drug company is testing a new medication's effectiveness for reducing blood pressure. The null hypothesis is that the drug has no effect on blood pressure. However, due to a statistical fluctuation or other factors, the study incorrectly detects a significant decrease in blood pressure and rejects the null hypothesis. This would be a Type 1 error since the drug actually has no effect on blood pressure, but the test mistakenly concludes otherwise.
#
# Type 2 error, also known as a false negative, occurs when the null hypothesis is not rejected even though it is false. In other words, it is the failure to reject a false null hypothesis. It represents the situation where the test fails to detect an effect or relationship when, in reality, there is one.
#
# Example scenario of a Type 2 error:
# Continuing with the previous example, suppose the new medication actually does reduce blood pressure, but the study fails to detect a significant decrease and does not reject the null hypothesis. This would be a Type 2 error since the drug does have an effect on blood pressure, but the test fails to conclude so.
#
# Type 1 and Type 2 errors are inversely related, meaning that reducing one type of error increases the probability of the other. Researchers often aim to balance the two types of errors by choosing an appropriate significance level (alpha) and sample size to minimize both types of errors.

# %% [markdown]
# Q4: Explain Bayes's theorem with an example.
#
#
# Bayes's theorem is a fundamental concept in probability theory that describes how to update or revise the probability of an event based on new evidence. It allows us to calculate the conditional probability of an event given prior knowledge or information.
#
# The theorem is stated as follows:
#
# P(A|B) = (P(B|A) * P(A)) / P(B)
#
# Where:
#
# P(A|B) is the probability of event A given event B has occurred (the posterior probability).
# P(B|A) is the probability of event B given event A has occurred (the likelihood).
# P(A) is the probability of event A occurring without any additional information (the prior probability).
# P(B) is the probability of event B occurring without any additional information (the marginal likelihood).
# To understand Bayes's theorem, let's consider an example:
#
# Suppose there is a rare disease that affects 1% of the population, and a test has been developed to detect the disease. The test is known to be 95% accurate, meaning that it correctly identifies 95% of the individuals who have the disease and 95% of the individuals who do not have the disease.
#
# Given this information, let's calculate the probability that a person has the disease if they test positive.
#
# Let:
#
# Event A: Having the disease
# Event B: Testing positive
# We are interested in calculating P(A|B), the probability of having the disease given a positive test result.
#
# Using Bayes's theorem, we can break down the calculation as follows:
#
# P(A|B) = (P(B|A) * P(A)) / P(B)
#
# P(A) = 0.01 (1% of the population has the disease, so the prior probability of having the disease is 0.01).
# P(B|A) = 0.95 (The test is 95% accurate, so the probability of testing positive given that a person has the disease is 0.95).
# P(B) = P(B|A) * P(A) + P(B|not A) * P(not A)
# = 0.95 * 0.01 + 0.05 * 0.99
# = 0.0095 + 0.0495
# = 0.059 (The probability of testing positive, taking into account both true positives and false positives).
#
# Now, substituting the values into Bayes's theorem:
#
# P(A|B) = (0.95 * 0.01) / 0.059
# = 0.0095 / 0.059
# ≈ 0.161 (approximately 16.1%)
#
# Therefore, if a person tests positive for the disease, their probability of actually having the disease is around 16.1%, despite the test's 95% accuracy. This example highlights the importance of considering the base rate of the disease when interpreting test results and demonstrates how Bayes's theorem allows us to update probabilities based on new evidence.

# %% [markdown]
# Q5: What is a confidence interval? How to calculate the confidence interval, explain with an example. words 100
#
#
# A confidence interval is a statistical range that provides an estimated range of values within which a population parameter, such as a mean or proportion, is likely to lie. It measures the uncertainty associated with sample estimates.
#
# To calculate a confidence interval, you typically follow these steps:
#
# Collect a representative sample from the population of interest.
# Compute the sample statistic (e.g., mean, proportion) based on the sample data.
# Determine the desired confidence level (e.g., 95%, 99%) that reflects your level of confidence in capturing the true population parameter.
# Identify the appropriate critical value from the corresponding probability distribution (e.g., z-value for a normal distribution, t-value for a t-distribution), based on the desired confidence level and sample size.
# Calculate the standard error, which quantifies the variability of the sample statistic.
# Use the sample statistic, critical value, and standard error to calculate the lower and upper bounds of the confidence interval.
# Example: Let's say you want to estimate the average height of adult males in a city. You collect a random sample of 100 males and find the mean height to be 175 cm, with a standard deviation of 5 cm.
#
# To calculate a 95% confidence interval for the population mean height:
#
# Sample mean: 175 cm
# Sample size: 100
# Desired confidence level: 95%
# Critical value: For a 95% confidence level, the critical value for a normal distribution is approximately 1.96.
# Standard error: Compute the standard error by dividing the sample standard deviation by the square root of the sample size. In this case, it would be 5 cm / sqrt(100) = 0.5 cm.
# Confidence interval calculation: Multiply the standard error by the critical value and add/subtract the result from the sample mean. The lower bound would be 175 cm - (1.96 * 0.5 cm), and the upper bound would be 175 cm + (1.96 * 0.5 cm).
# Therefore, the 95% confidence interval for the average height of adult males in the city would be (174.02 cm, 175.98 cm), indicating that we are 95% confident that the true population mean height falls within this interval.

# %% [markdown]
# Q6. Use Bayes' Theorem to calculate the probability of an event occurring given prior knowledge of the
# event's probability and new evidence. Provide a sample problem and solution.  100 words
#
#
# Here's a sample problem and solution using Bayes' Theorem:
#
# Problem:
# A factory produces two types of products: Product A and Product B. Product A has a defect rate of 5%, while Product B has a defect rate of 10%. If a randomly selected product is found to be defective, what is the probability that it is Product A?
#
# Solution:
# Let's define the events:
# A: Product A
# B: Defective product
#
# Given:
# P(A) = 0.5 (prior probability of selecting Product A)
# P(B|A) = 0.05 (probability of a defective product given Product A)
#
# We want to calculate:
# P(A|B) (probability of selecting Product A given a defective product)
#
# To calculate P(A|B) using Bayes' Theorem:
# P(B) = P(B|A) * P(A) + P(B|not A) * P(not A)
#
# Since we have only two products (A and B), P(not A) = 1 - P(A) = 1 - 0.5 = 0.5.
# Assuming a defective Product B has a 10% probability (P(B|not A) = 0.1), we can calculate P(B):
# P(B) = 0.05 * 0.5 + 0.1 * 0.5 = 0.025 + 0.05 = 0.075
#
# Finally, we can calculate P(A|B) using Bayes' Theorem:
# P(A|B) = (P(B|A) * P(A)) / P(B) = (0.05 * 0.5) / 0.075 = 0.333 (approximately 33.3%)
#
# Therefore, given a randomly selected defective product, there is approximately a 33.3% chance it is Product A.

# %% [markdown]
# Q7. Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation
# of 5. Interpret the results.  100 words
#
#
# To calculate the 95% confidence interval for a sample with a mean of 50 and a standard deviation of 5, we can use the following formula:
#
# Confidence Interval = Sample Mean ± (Critical Value * Standard Error)
#
# Assuming a large sample size, the critical value for a 95% confidence level is approximately 1.96. The standard error is calculated by dividing the standard deviation by the square root of the sample size.
#
# Let's assume a sample size of 100:
#
# Standard Error = 5 / √100 = 0.5
#
# Confidence Interval = 50 ± (1.96 * 0.5) = (49.02, 50.98)
#
# Interpretation: The 95% confidence interval for the population mean based on this sample data is approximately (49.02, 50.98). This means that we are 95% confident that the true population mean falls within this range.

# %% [markdown]
# Q9. Calculate the z-score for a data point with a value of 75, a population mean of 70, and a population
# standard deviation of 5. Interpret the results.
#
#
# To calculate the z-score for a data point with a value of 75, a population mean of 70, and a population standard deviation of 5, we can use the formula:
#
# z-score = (x - μ) / σ
#
# where:
# x = data point value
# μ = population mean
# σ = population standard deviation
#
# Plugging in the given values:
#
# z-score = (75 - 70) / 5 = 1

# %% [markdown]
# Q10. In a study of the effectiveness of a new weight loss drug, a sample of 50 participants lost an average
# of 6 pounds with a standard deviation of 2.5 pounds. Conduct a hypothesis test to determine if the drug is
# significantly effective at a 95% confidence level using a t-test.
#
# To conduct a hypothesis test to determine if the weight loss drug is significantly effective at a 95% confidence level using a t-test, we need to set up the null and alternative hypotheses and perform the necessary calculations.
#
# Null Hypothesis (H0): The weight loss drug is not significantly effective. The average weight loss is not different from zero.
# Alternative Hypothesis (H1): The weight loss drug is significantly effective. The average weight loss is different from zero.
#
# Given:
# Sample size (n) = 50
# Sample mean (x̄) = 6 pounds
# Sample standard deviation (s) = 2.5 pounds
# Confidence level = 95%
#
# Since the population standard deviation is unknown, we'll use a t-test for this analysis.
#
# Set the significance level (α): α = 1 - confidence level = 0.05 (for a 95% confidence level).
#
# Calculate the t-statistic:
# t = (x̄ - μ) / (s / √n)
# Where μ is the hypothesized population mean (0, as we are testing if the average weight loss is different from zero).
#
# t = (6 - 0) / (2.5 / √50)
# t ≈ 19.10
#
# Determine the degrees of freedom (df): df = n - 1 = 50 - 1 = 49.
#
# Calculate the critical t-value based on the significance level and degrees of freedom using a t-table or statistical software. For a two-tailed test at α = 0.05 and df = 49, the critical t-value is approximately ±2.01.
#
# Compare the calculated t-value to the critical t-value:
# Since |t| (absolute value of t) > critical t-value, we reject the null hypothesis.

# %% [markdown]
# Q11. In a survey of 500 people, 65% reported being satisfied with their current job. Calculate the 95%
# confidence interval for the true proportion of people who are satisfied with their job.
#
#
# To calculate the 95% confidence interval for the true proportion of people who are satisfied with their job based on the survey results, we can use the following formula:
#
# Confidence Interval = Sample Proportion ± (Critical Value * Standard Error)
#
# Given:
# Sample size (n) = 500
# Sample proportion (p̂) = 0.65 (65% reported being satisfied)
# Confidence level = 95%
#
# Calculate the standard error:
# Standard Error = √((p̂ * (1 - p̂)) / n)
# Standard Error = √((0.65 * (1 - 0.65)) / 500) ≈ 0.015
#
# Determine the critical value based on the confidence level. For a 95% confidence level, the critical value for a normal distribution is approximately 1.96.
#
# Calculate the lower and upper bounds of the confidence interval:
# Lower bound = 0.65 - (1.96 * 0.015)
# Upper bound = 0.65 + (1.96 * 0.015)
#
# Lower bound ≈ 0.621
# Upper bound ≈ 0.679
#
# Interpretation: The 95% confidence interval for the true proportion of people who are satisfied with their job based on the survey is approximately (0.621, 0.679). This means that we can be 95% confident that the true proportion of people satisfied with their job falls within this interval.

# %% [markdown]
# User
# Q12. A researcher is testing the effectiveness of two different teaching methods on student performance.
# Sample A has a mean score of 85 with a standard deviation of 6, while sample B has a mean score of 82
# with a standard deviation of 5. Conduct a hypothesis test to determine if the two teaching methods have a
# significant difference in student performance using a t-test with a significance level of 0.01.
#
#
# To conduct a hypothesis test to determine if the two teaching methods have a significant difference in student performance, we can use a t-test with a significance level of 0.01.
#
# Null Hypothesis (H0): There is no significant difference in student performance between the two teaching methods. The population means are equal.
# Alternative Hypothesis (H1): There is a significant difference in student performance between the two teaching methods. The population means are not equal.
#
# Given:
# Sample A:
# Sample mean (x̄A) = 85
# Sample standard deviation (sA) = 6
# Sample size (nA) - assumed to be equal to the sample size of Sample B
# Sample B:
# Sample mean (x̄B) = 82
# Sample standard deviation (sB) = 5
#
# Significance level (α) = 0.01
#
# Assumptions:
#
# The samples are independent.
# The populations are normally distributed or have a large enough sample size for the Central Limit Theorem to apply.
# To perform the hypothesis test:
#
# Calculate the test statistic, which is the t-value:
# t = (x̄A - x̄B) / sqrt((sA^2 / nA) + (sB^2 / nB))
# t = (85 - 82) / sqrt((6^2 / nA) + (5^2 / nB))
#
# Determine the degrees of freedom (df) using the formula:
# df = nA + nB - 2
#
# Calculate the critical t-value based on the significance level (α) and degrees of freedom (df). For a two-tailed test with α = 0.01 and df, look up the critical t-value from a t-distribution table or use statistical software.
#
# Compare the calculated t-value with the critical t-value:
# If the calculated t-value falls outside the range defined by the critical t-values, we reject the null hypothesis and conclude that there is a significant difference in student performance between the two teaching methods.

# %% [markdown]
# Q13. A population has a mean of 60 and a standard deviation of 8. A sample of 50 observations has a mean
# of 65. Calculate the 90% confidence interval for the true population mean.
#
#
# To calculate the 90% confidence interval for the true population mean based on the given information, we can use the following formula:
#
# Confidence Interval = Sample Mean ± (Critical Value * (Standard Deviation / √(Sample Size)))
#
# Given:
# Population mean (μ) = 60
# Population standard deviation (σ) = 8
# Sample size (n) = 50
# Sample mean (x̄) = 65
# Confidence level = 90%
#
# Calculate the critical value based on the confidence level. For a 90% confidence level and a large sample size (n > 30), the critical value is approximately 1.645 (obtained from the standard normal distribution or a t-distribution table).
#
# Calculate the standard error:
# Standard Error = Standard Deviation / √(Sample Size)
# Standard Error = 8 / √50 ≈ 1.131
#
# Calculate the lower and upper bounds of the confidence interval:
# Lower bound = Sample Mean - (Critical Value * Standard Error)
# Lower bound = 65 - (1.645 * 1.131)
# Lower bound ≈ 63.51
#
# Upper bound = Sample Mean + (Critical Value * Standard Error)
# Upper bound = 65 + (1.645 * 1.131)
# Upper bound ≈ 66.49
#
# Interpretation: The 90% confidence interval for the true population mean, based on the given sample, is approximately (63.51, 66.49). This means that we can be 90% confident that the true population mean falls within this interval.

# %% [markdown]
# Q14. In a study of the effects of caffeine on reaction time, a sample of 30 participants had an average
# reaction time of 0.25 seconds with a standard deviation of 0.05 seconds. Conduct a hypothesis test to
# determine if the caffeine has a significant effect on reaction time at a 90% confidence level using a t-test.
#
#
# To conduct a hypothesis test to determine if caffeine has a significant effect on reaction time at a 90% confidence level using a t-test, we need to set up the null and alternative hypotheses and perform the necessary calculations.
#
# Null Hypothesis (H0): Caffeine does not have a significant effect on reaction time. The population mean reaction time is not different from the sample mean.
# Alternative Hypothesis (H1): Caffeine has a significant effect on reaction time. The population mean reaction time is different from the sample mean.
#
# Given:
# Sample size (n) = 30
# Sample mean (x̄) = 0.25 seconds
# Sample standard deviation (s) = 0.05 seconds
# Confidence level = 90%
#
# Since the population standard deviation is unknown, we'll use a t-test for this analysis.
#
# Set the significance level (α): α = 1 - confidence level = 0.1 (for a 90% confidence level).
#
# Calculate the t-statistic:
# t = (x̄ - μ) / (s / √n)
# Where μ is the hypothesized population mean (0, as we are testing if there is a significant effect of caffeine on reaction time).
#
# t = (0.25 - 0) / (0.05 / √30)
# t ≈ 17.32
#
# Determine the degrees of freedom (df): df = n - 1 = 30 - 1 = 29.
#
# Calculate the critical t-value based on the significance level and degrees of freedom using a t-table or statistical software. For a two-tailed test at α = 0.1 and df = 29, the critical t-value is approximately ±1.699.
#
# Compare the calculated t-value to the critical t-value:
# Since |t| (absolute value of t) > critical t-value, we reject the null hypothesis.
#
# Conclusion: Based on the results of the t-test, at a 90% confidence level, we have evidence to suggest that caffeine has a significant effect on reaction time. The population mean reaction time is significantly different from the sample mean.
